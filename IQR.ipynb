# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod5-Statistics\TW\customer
#
# 10/25/2023  10:11 PM    <DIR>          .
# 10/25/2023  10:11 PM    <DIR>          ..
# 10/25/2023  11:52 AM    <DIR>          .ipynb_checkpoints
# 10/25/2023  10:10 PM           369,525 karthika.IQR.ipynb
# 10/19/2023  09:43 AM           453,248 shopping_trends.csv
# 10/19/2023  09:43 AM           416,614 shopping_trends_updated.csv
# 10/25/2023  12:01 PM           136,570 Teamwork.ipynb
# 10/25/2023  08:53 AM           135,600 Teamwork.karthika.ipynb
#                5 File(s)      1,511,557 bytes
#                3 Dir(s)  61,159,374,848 bytes free

# %%
trends = pd.read_csv("shopping_trends.csv",index_col=[0])
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.shape  # 3900 rows and 18 columns
# Out:
# (3900, 18)

# %%
trends.columns
# Out:
# Index(['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
trends.isnull().sum() # doesnt exist NAN values
# Out:
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
trends.dtypes # datatypes of each columns
# Out:
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
trends.boxplot(by="Season",column="Purchase Amount (USD)")
plt.ylabel("Purchase Amount")
plt.xlabel("Season")
# Out:
# Text(0.5, 0, 'Season')

# %% [markdown]
# * min-same for all season [20]
# * max-same for all season [100]
#
# IQR
#
# *25% -fall -41
#       spring-37
#       summer-38
#       winter-40
#
# *median -fall -62
#          spring-58
#          summer-58
#          winter-62
#
# *75% -fall -83
#       spring-79
#       summer-79
#       winter-80

# %%
trends[(trends["Season"]=="Fall")].describe()
# Out:
#               Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  975.000000             975.000000     975.000000          975.000000
# mean    44.391795              61.556923       3.729949           24.970256
# std     15.065577              23.745022       0.711944           14.539126
# min     18.000000              20.000000       2.500000            1.000000
# 25%     32.000000              41.000000       3.100000           12.000000
# 50%     45.000000              62.000000       3.700000           24.000000
# 75%     57.500000              83.000000       4.300000           38.000000
# max     70.000000             100.000000       5.000000           50.000000

# %%
trends[(trends["Season"]=="Spring")].describe()
# Out:
#               Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  999.000000             999.000000     999.000000          999.000000
# mean    44.582583              58.737738       3.790591           25.116116
# std     15.534851              23.935855       0.725551           14.181706
# min     18.000000              20.000000       2.500000            1.000000
# 25%     31.000000              37.000000       3.150000           14.000000
# 50%     45.000000              58.000000       3.800000           25.000000
# 75%     58.000000              79.500000       4.400000           37.000000
# max     70.000000             100.000000       5.000000           50.000000

# %%
trends[(trends["Season"]=="Summer")].describe()
# Out:
#               Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  955.000000             955.000000     955.000000          955.000000
# mean    43.973822              58.405236       3.725654           25.408377
# std     15.098084              23.470580       0.715493           14.657971
# min     18.000000              20.000000       2.500000            1.000000
# 25%     30.000000              37.500000       3.100000           13.000000
# 50%     44.000000              58.000000       3.700000           26.000000
# 75%     57.000000              79.000000       4.400000           38.000000
# max     70.000000             100.000000       5.000000           50.000000

# %%
trends[(trends["Season"]=="Winter")].describe()
# Out:
#              Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  971.00000             971.000000     971.000000          971.000000
# mean    43.30793              60.357364       3.752111           25.920700
# std     15.10796              23.475475       0.710774           14.420092
# min     18.00000              20.000000       2.500000            1.000000
# 25%     30.00000              40.000000       3.200000           13.000000
# 50%     43.00000              62.000000       3.700000           26.000000
# 75%     56.00000              80.000000       4.300000           38.500000
# max     70.00000             100.000000       5.000000           50.000000

# %%
trends.boxplot(by="Gender",column="Age")
plt.xlabel("Gender")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# * min-same for both gender below 20[18]
# * min-same for both gender is 70
#
# *25% -female -31
#       male-31
# *50% -female -44
#       male-44
# *75% -female -57
#       male-57

# %%
trends[(trends["Gender"]=="Male")].describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  2652.000000            2652.000000    2652.000000         2652.000000
# mean     44.097285              59.536199       3.753959           25.707014
# std      15.328257              23.809976       0.714243           14.373570
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              38.000000       3.100000           13.750000
# 50%      44.000000              60.000000       3.800000           26.000000
# 75%      57.000000              80.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
trends[(trends["Gender"]=="Female")].describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  1248.000000            1248.000000    1248.000000         1248.000000
# mean     44.007212              60.249199       3.741426           24.596154
# std      14.953843              23.420556       0.720625           14.579221
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              40.000000       3.100000           12.000000
# 50%      44.000000              60.000000       3.700000           24.000000
# 75%      57.000000              81.000000       4.300000           37.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
trends.boxplot(by="Category",column="Review Rating")
plt.xlabel("Category")
plt.ylabel("Review Rating")
# Out:
# Text(0, 0.5, 'Review Rating')

# %% [markdown]
# min same[2.5]
# max same[5.0]
#
# 25% -between 3.0 to 3.5
#     acc and ftwear 3.2
#     clthng and outrwear 3.1
#
# 50% -between 3.5 to 4.0
#     acc,ftwear and outrwear 3.8
#     clthing 3.7
#
# 75%-between 4.0 to 4.5
#     acc and ftwear 4.4
#     clthng and outrwear 4.3

# %%
plt.hist(data=trends,x="Age",bins=30, edgecolor='black',color='pink')
plt.xlabel('Age')
plt.ylabel('counts')
plt.grid()
plt.show()

# %%
trends.hist(bins=50, edgecolor='black',color='pink',figsize=(20,15))
plt.show()

# %%
trends.boxplot(by="Size",column="Age")
plt.xlabel("Size")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# age and sizes corresponding to age is same for sizes

# %%
sns.histplot(trends[["Purchase Amount (USD)","Previous Purchases"]],bins=20,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(trends[["Age","Review Rating"]],bins=20,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(trends[["Age","Purchase Amount (USD)"]],bins=20,kde=True)
plt.grid()
plt.show()
