# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod5-Statistics\TW\customer
#
# 10/19/2023  10:20 AM    <DIR>          .
# 10/19/2023  10:20 AM    <DIR>          ..
# 10/19/2023  09:50 AM    <DIR>          .ipynb_checkpoints
# 10/19/2023  09:43 AM           453,248 shopping_trends.csv
# 10/19/2023  09:43 AM           416,614 shopping_trends_updated.csv
# 10/19/2023  10:20 AM            39,336 Teamwork.ipynb
#                3 File(s)        909,198 bytes
#                3 Dir(s)  62,917,955,584 bytes free

# %%
trends = pd.read_csv("shopping_trends.csv",index_col=[0])
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends_updated = pd.read_csv("shopping_trends_updated.csv",index_col=[0])
trends_updated
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.shape  # 3900 rows and 18 columns
# Out:
# (3900, 18)

# %%
trends_updated.shape  # 3900 rows and 17 columns
# Out:
# (3900, 17)

# %%
trends.isnull().sum() # doesnt exist NAN values
# Out:
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
trends.columns # columns name
# Out:
# Index(['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
trends.dtypes # datatypes of each columns
# Out:
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
trends["Category"].value_counts() # there are 4 different categories,
# Out:
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: Category, dtype: int64

# %%
trends["Season"].value_counts() # almost all season shopping trend is similar
# Out:
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: Season, dtype: int64

# %%
trends["Gender"].value_counts()# male did more shopping than female
# Out:
# Male      2652
# Female    1248
# Name: Gender, dtype: int64

# %%
trends["Age"].max() #
# Out:
# 70

# %%
trends["Age"].min()
# Out:
# 18

# %%
trends[trends["Age"].between(60,70)]
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 7             63    Male          Shirt     Clothing                     85
# 13            61    Male           Coat    Outerwear                     72
# 14            65    Male          Dress     Clothing                     51
# 15            64    Male           Coat    Outerwear                     53
# 16            64    Male          Skirt     Clothing                     81
# ...          ...     ...            ...          ...                    ...
# 3875          70  Female        Sweater     Clothing                     54
# 3876          63  Female            Hat  Accessories                     51
# 3877          60  Female          Shoes     Footwear                     85
# 3879          60  Female            Hat  Accessories                     42
# 3895          66  Female          Skirt     Clothing                     78
#
# ...

# %%
category_group = trends.groupby("Category")

# %%
category_group["Item Purchased"].value_counts()
# Out:
# Category     Item Purchased
# Accessories  Jewelry           171
#              Belt              161
#              Sunglasses        161
#              Scarf             157
#              Hat               154
#              Handbag           153
#              Backpack          143
#              Gloves            140
# Clothing     Blouse            171
#              Pants             171
#              Shirt             169
#              Dress             166
#              Sweater           164
#              Socks             159
#              Skirt             158
#              Shorts            157
#              Hoodie            151
#              T-shirt           147
#              Jeans             124
# Footwear     Sandals           160
#              Shoes             150
#              Sneakers          145
#              Boots             144
# Outerwear    Jacket            163
#              Coat              161
# Name: Item Purchased, dtype: int64

# %%
pay_method_group = trends.groupby("Payment Method")

# %%
pay_method_group[["Category","Item Purchased","Purchase Amount (USD)"]].get_group("Credit Card")
# Out:
#                 Category Item Purchased  Purchase Amount (USD)
# Customer ID
# 1               Clothing         Blouse                     53
# 11              Footwear          Shoes                     34
# 16              Clothing          Skirt                     81
# 21              Clothing          Pants                     51
# 22              Clothing          Pants                     62
# ...                  ...            ...                    ...
# 3872            Clothing        T-shirt                     97
# 3881            Clothing          Shirt                     20
# 3883            Clothing          Pants                     95
# 3891            Clothing          Shirt                     81
# 3898         Accessories           Belt                     33
#
# [696 rows x 3 columns]

# %%
pay_method_group[["Category","Item Purchased"]].get_group("Credit Card").value_counts()
# Out:
# Category     Item Purchased
# Accessories  Sunglasses        41
# Clothing     T-shirt           37
#              Pants             36
#              Blouse            35
# Accessories  Scarf             32
# Clothing     Dress             32
# Accessories  Belt              32
#              Jewelry           31
# Clothing     Shorts            30
#              Socks             30
# Accessories  Handbag           29
# Clothing     Sweater           29
# Accessories  Hat               28
# Footwear     Shoes             28
# Clothing     Hoodie            27
# Accessories  Gloves            27
# Outerwear    Coat              25
# Accessories  Backpack          25
# Clothing     Skirt             25
#              Shirt             23
# Footwear     Sneakers          23
# Outerwear    Jacket            23
# Footwear     Sandals           19
# Clothing     Jeans             15
# Footwear     Boots             14
# dtype: int64

# %%
pay_method_group[["Category","Item Purchased","Season"]].get_group("Credit Card").min()
# Out:
# Category          Accessories
# Item Purchased       Backpack
# Season                   Fall
# dtype: object

# %%
trends1 = trends.loc[:,["","Season"]]

# %%
plt.bar(trends["Category"],trends["Payment Method"])
plt.xlabel("Season ")
plt.ylabel("Payment Method")
plt.grid()
plt.show()

# %%
trends_sam = trends.loc[:,:]
trends.plot(kind="bar")
plt.show()

# %%
trends[trends["Age"].between(18,25)].shape
# Out:
# (571, 18)

# %%
trends[trends["Age"].between(26,35)].shape
# Out:
# (742, 18)

# %%
trends[trends["Age"].between(36,45)].shape
# Out:
# (729, 18)

# %%
trends[trends["Age"].between(46,50)].shape
# Out:
# (382, 18)

# %%
trends[trends["Age"].between(51,60)].shape
# Out:
# (753, 18)

# %%
trends[trends["Age"].between(61,70)].shape
# Out:
# (723, 18)

# %%
trends[trends["Age"].between(36,70)].shape
# Out:
# (2587, 18)

# %%
trends[trends["Age"].between(18,35)].shape
# Out:
# (1313, 18)

# %%
trends[trends["Age"].between(36,45)].shape
# Out:
# (729, 18)

# %%
trends[trends["Age"].between(46,70)].shape
# Out:
# (1858, 18)

# %%
trends[trends["Age"].between(50,55)].shape # customers between 50-55 were spend more on shoppings
# Out:
# (454, 18)

# %%
trends[trends["Age"].between(56,60)].shape
# Out:
# (382, 18)

# %%
female_with_accessories = trends[(trends["Gender"]=="Female") & (trends["Category"]=="Accessories") ] 
female_with_accessories
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 2656          26  Female     Sunglasses  Accessories                     83
# 2659          52  Female        Handbag  Accessories                     47
# 2665          22  Female        Jewelry  Accessories                     84
# 2670          39  Female           Belt  Accessories                     28
# 2671          30  Female     Sunglasses  Accessories                     44
# ...          ...     ...            ...          ...                    ...
# 3893          35  Female        Jewelry  Accessories                     86
# 3894          21  Female            Hat  Accessories                     64
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3900          52  Female        Handbag  Accessories                     81
#
# ...
